# %%
from keras.models import load_model
from keras.preprocessing import image
import numpy as np

# %%
import deepface

# %%
model = load_model(r'D:\EE 308\facereco.h5')
model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
img_width, img_height = 160,160
img = image.load_img(r'D:\EE 308\val\Abdullah_Gul\Abdullah_Gul_0006.jpg', target_size=(img_width, img_height))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)

# %%
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
img_preprocessed = preprocess_input(x)

# %%
prediction = model.predict(img_preprocessed)

# %%
##from sklearn.preprocessing import LabelEncoder
#enc=LabelEncoder()
####enc.fit(ARRAY)
#print(enc.inverse_transform(prediction))

# %%
import cv2

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 160, 160, 3) 0
# __________________________________________________________________________________________________
# Conv2d_1a_3x3 (Conv2D)          (None, 79, 79, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# Conv2d_1a_3x3_BatchNorm (BatchN (None, 79, 79, 32)   96          Conv2d_1a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv2d_1a_3x3_Activation (Activ (None, 79, 79, 32)   0           Conv2d_1a_3x3_BatchNorm[0][0]
# __________________________________________________________________________________________________
# ...

# %%
from deepface import DeepFace
obj = DeepFace.analyze(img_path = r"D:\EE 308\val\Abdullah_Gul\Abdullah_Gul_0006.jpg", actions = ['age', 'gender', 'emotion'])
print(obj["age"]," years old "," ",obj["dominant_emotion"]," ", obj["gender"])
# Out:
# ...
# Action: age:   0%|                                                                               | 0/3 [00:00<?, ?it/s]
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000023E0107ACA8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...
# Action: emotion: 100%|███████████████████████████████████████████████████████████████████| 3/3 [00:21<00:00,  7.19s/it]
# ...

# %%
from matplotlib import pyplot as plt
import cv2

img = cv2.imread(r'D:\EE 308\val\Abdullah_Gul\Abdullah_Gul_0006.jpg')
plt.imshow(img)
plt.show()

# %%
obj = DeepFace.analyze(img_path = r"D:\EE 308\my_photo.jpg", actions = ['age', 'gender', 'emotion'])
print(obj["age"]," years old "," ",obj["dominant_emotion"]," ", obj["gender"])
# Out:
# ...
# Action: age:   0%|                                                                               | 0/3 [00:00<?, ?it/s]
# WARNING:tensorflow:5 out of the last 23 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000023E7C9EC558> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...
# Action: emotion: 100%|███████████████████████████████████████████████████████████████████| 3/3 [00:08<00:00,  2.76s/it]
# ...

# %%
img = cv2.imread(r'D:\EE 308\my_photo.jpg')
plt.imshow(img)
plt.show()

# %%
#code for group recognition in face reco(dlib add later), else count using haarcascade

# %%
img3 = cv2.imread(r'D:\EE 308\twin.jpg')
plt.imshow(img3)
plt.show()

# %%
face_cascade = cv2.CascadeClassifier('D:\EE 308\haarcascade_frontalface_default.xml')
grayImage = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(grayImage)
print (type(faces))
print (faces)
# Out:
# <class 'numpy.ndarray'>
# [[ 59  37  42  42]
#  [132  39  40  40]]

# %%
print (faces.shape)
print ("Number of faces detected: " + str(faces.shape[0]))
# Out:
# (2, 4)
# Number of faces detected: 2

# %%
from datetime import datetime
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
print("date and time =", dt_string)
# Out:
# now = 2021-03-04 22:01:04.209717
# date and time = 04/03/2021 22:01:04
